# %%
from pathlib import Path
import sys
import os
from torch_geometric.loader import DataLoader
project_dir = Path.cwd()
for p in [project_dir, *project_dir.parents]:
    if (p / "SYMBA-GSoC2026" / "src").exists():
        sys.path.insert(0, str(p / "SYMBA-GSoC2026"))
        sys.path.insert(0, str(p / "SYMBA-GSoC2026" / "src"))
        break
    
from src.utils.config import ProjectConfig
from src.models.graphSYMKAN import GraphSYMKANModel
from src.train.training import Trainer
# %load_ext autoreload
# %autoreload 2
cfg = ProjectConfig()
model = GraphSYMKANModel(cfg, tgt_vocab_size=100)
print("Model successfully loaded from modules!")
# Out:
# Model successfully loaded from modules!

# %%
import torch
from torch_geometric.loader import DataLoader

DATA_DIR = Path("../preprocessed")


print("Loading PyG Tensors...")
train_data = torch.load(DATA_DIR / 'train_graphs.pt', weights_only=False)
val_data = torch.load(DATA_DIR / 'val_graphs.pt', weights_only=False)


train_dataset = train_data['dataset']
val_dataset = val_data['dataset']
global_vocab = train_data['vocab']

print(f"Train Graphs: {len(train_dataset)}")
print(f"Val Graphs: {len(val_dataset)}")
print(f"Vocabulary Size: {len(global_vocab)}")

train_loader = DataLoader(train_dataset, batch_size=cfg.BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=cfg.BATCH_SIZE, shuffle=False)

print("DataLoaders ready")
# Out:
# Loading PyG Tensors...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 8
#       4 DATA_DIR = Path("../preprocessed")
#       7 print("Loading PyG Tensors...")
# ----> 8 train_data = torch.load(DATA_DIR / 'train_graphs.pt', weights_only=False)
#       9 val_data = torch.load(DATA_DIR / 'val_graphs.pt', weights_only=False)
#      12 train_dataset = train_data['dataset']
#
# File c:\Users\manju\OneDrive\Documents\front-end\GNNKAN\venv\Lib\site-packages\torch\serialization.py:1500, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1497 if "encoding" not in pickle_load_args:
#    1498     pickle_load_args["encoding"] = "utf-8"
# -> 1500 with _open_file_like(f, "rb") as opened_file:
#    1501     if _is_zipfile(opened_file):
#    1502         # The zipfile reader is going to advance the current file position.
# ...
